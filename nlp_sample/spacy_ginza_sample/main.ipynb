# %%
import spacy
nlp = spacy.load('ja_ginza')

# %%
for p in nlp.pipeline:
    print(p)
# Out:
# ('tagger', <spacy.pipeline.pipes.Tagger object at 0x113836ca0>)
# ('parser', <spacy.pipeline.pipes.DependencyParser object at 0x12bdf5a00>)
# ('ner', <spacy.pipeline.pipes.EntityRecognizer object at 0x12bdf5b20>)
# ('CompoundSplitter', <ginza.compound_splitter.CompoundSplitter object at 0x1132fc4f0>)
# ('BunsetuRecognizer', <ginza.bunsetu_recognizer.BunsetuRecognizer object at 0x11ec99eb0>)

# %%
text = '本作は同じゲームエンジンを使用して、3つの異なるゲームモードとして提供している。「世界を救え」モードは、最大4人のプレイヤーがゾンビのようなモンスターを撃退し、オブジェクトを防御する協力型CO-OPモード (PvE)。「バトルロイヤル」モードは基本プレイ無料でプレイできるバトルロイヤルゲームであり、最大100人のプレイヤーが最後まで生き残るために他のプレイヤーと対戦する。「クリエイティブ」モードでは、プレイヤーが独自の世界を作成することができる。'

# %%
doc = nlp(text)
for s in doc.sents:
    print(s)
# Out:
# 本作は同じゲームエンジンを使用して、3つの異なるゲームモードとして提供している。
# 「世界を救え」モードは、最大4人のプレイヤーがゾンビのようなモンスターを撃退し、オブジェクトを防御する協力型CO-OPモード (PvE)。
# 「バトルロイヤル」モードは基本プレイ無料でプレイできるバトルロイヤルゲームであり、最大100人のプレイヤーが最後まで生き残るために他のプレイヤーと対戦する。
# 「クリエイティブ」モードでは、プレイヤーが独自の世界を作成することができる。

# %%
for np in doc.noun_chunks:
    print(np)
# Out:
# 本作
# 同じゲームエンジン
# 3つ
# ゲームモード
# 「世界
# 救え」モード
# オブジェクト
# 協力型CO-OPモード (PvE
# 「バトルロイヤル」モード
# 基本プレイ無料
# 最大100人
# プレイヤー
# 最後
# 他
# プレイヤー
# 「クリエイティブ」モード
# プレイヤー
# 独自の世界

# %%
for token in doc:
    print(token.text)
# Out:
# 本作
# は
# 同じ
# ゲーム
# エンジン
# を
# 使用
# し
# て
# 、
# 3
# つ
# の
# 異なる
# ゲーム
# モード
# と
# し
# て
# 提供
# し
# て
# いる
# 。
# 「
# 世界
# を
# 救え
# 」
# モード
# は
# 、
# 最大
# 4
# 人
# の
# プレイヤー
# が
# ゾンビ
# の
# よう
# な
# モンスター
# を
# 撃退
# し
# 、
# オブジェクト
# を
# 防御
# する
# 協力
# 型
# CO-OP
# モード
# (
# PvE
# )
# 。
# 「
# バトルロイヤル
# 」
# モード
# は
# 基本
# プレイ
# 無料
# で
# プレイ
# できる
# バトルロイヤル
# ゲーム
# で
# あり
# 、
# 最大
# 100
# 人
# の
# プレイヤー
# が
# 最後
# まで
# 生き残る
# ため
# に
# 他
# の
# プレイヤー
# と
# 対戦
# する
# 。
# 「
# クリエイティブ
# 」
# モード
# で
# は
# 、
# プレイヤー
# が
# 独自
# の
# 世界
# を
# 作成
# する
# こと
# が
# できる
# 。

# %%
for token in doc:
    print(f'token[{token.i}] = {token.text}, {token.pos_}, {token.dep_}, {token.head.i}')
# Out:
# token[0] = 本作, NOUN, nsubj, 19
# token[1] = は, ADP, case, 0
# token[2] = 同じ, DET, amod, 4
# token[3] = ゲーム, NOUN, compound, 4
# token[4] = エンジン, NOUN, obj, 6
# token[5] = を, ADP, case, 4
# token[6] = 使用, VERB, advcl, 19
# token[7] = し, AUX, advcl, 6
# token[8] = て, SCONJ, mark, 6
# token[9] = 、, PUNCT, punct, 6
# token[10] = 3, NUM, nummod, 11
# token[11] = つ, NOUN, nsubj, 13
# token[12] = の, ADP, case, 11
# token[13] = 異なる, VERB, acl, 15
# token[14] = ゲーム, NOUN, compound, 15
# token[15] = モード, NOUN, obl, 19
# token[16] = と, ADP, case, 15
# token[17] = し, VERB, fixed, 16
# token[18] = て, SCONJ, fixed, 16
# token[19] = 提供, VERB, ROOT, 19
# token[20] = し, AUX, advcl, 19
# token[21] = て, SCONJ, mark, 19
# token[22] = いる, AUX, aux, 19
# token[23] = 。, PUNCT, punct, 19
# token[24] = 「, PUNCT, punct, 25
# token[25] = 世界, NOUN, obj, 29
# token[26] = を, ADP, case, 25
# token[27] = 救え, VERB, compound, 29
# token[28] = 」, PUNCT, punct, 29
# token[29] = モード, NOUN, nsubj, 56
# token[30] = は, ADP, case, 29
# token[31] = 、, PUNCT, punct, 29
# token[32] = 最大, NOUN, compound, 34
# token[33] = 4, NUM, nummod, 34
# token[34] = 人, NOUN, nmod, 36
# token[35] = の, ADP, case, 34
# token[36] = プレイヤー, NOUN, nsubj, 44
# token[37] = が, ADP, case, 36
# token[38] = ゾンビ, NOUN, nmod, 40
# token[39] = の, ADP, case, 38
# token[40] = よう, NOUN, acl, 42
# token[41] = な, AUX, cop, 40
# token[42] = モンスター, NOUN, obj, 44
# token[43] = を, ADP, case, 42
# token[44] = 撃退, VERB, compound, 29
# token[45] = し, AUX, aux, 44
# token[46] = 、, PUNCT, punct, 44
# token[47] = オブジェクト, NOUN, obj, 49
# token[48] = を, ADP, case, 47
# token[49] = 防御, VERB, acl, 56
# token[50] = する, AUX, aux, 49
# token[51] = 協力, NOUN, compound, 56
# token[52] = 型, NOUN, compound, 56
# token[53] = CO-OP, NOUN, compound, 56
# token[54] = モード, NOUN, compound, 53
# token[55] = (, PUNCT, punct, 53
# token[56] = PvE, NOUN, ROOT, 56
# token[57] = ), PUNCT, punct, 56
# token[58] = 。, PUNCT, punct, 56
# token[59] = 「, PUNCT, punct, 62
# token[60] = バトルロイヤル, PROPN, compound, 62
# token[61] = 」, PUNCT, punct, 62
# token[62] = モード, NOUN, nsubj, 71
# token[63] = は, ADP, case, 62
# token[64] = 基本, NOUN, compound, 66
# token[65] = プレイ, NOUN, compound, 66
# token[66] = 無料, NOUN, obl, 68
# token[67] = で, ADP, case, 66
# token[68] = プレイ, VERB, acl, 71
# token[69] = できる, AUX, aux, 68
# token[70] = バトルロイヤル, PROPN, compound, 71
# token[71] = ゲーム, NOUN, advcl, 90
# token[72] = で, AUX, cop, 71
# token[73] = あり, AUX, aux, 71
# token[74] = 、, PUNCT, punct, 71
# token[75] = 最大, NOUN, compound, 77
# token[76] = 100, NUM, nummod, 77
# token[77] = 人, NOUN, nmod, 79
# token[78] = の, ADP, case, 77
# token[79] = プレイヤー, NOUN, nsubj, 83
# token[80] = が, ADP, case, 79
# token[81] = 最後, NOUN, obl, 83
# token[82] = まで, ADP, case, 81
# token[83] = 生き残る, VERB, advcl, 90
# token[84] = ため, NOUN, mark, 83
# token[85] = に, ADP, mark, 83
# token[86] = 他, NOUN, nmod, 88
# token[87] = の, ADP, case, 86
# token[88] = プレイヤー, NOUN, obl, 90
# token[89] = と, ADP, case, 88
# token[90] = 対戦, VERB, ROOT, 90
# token[91] = する, AUX, aux, 90
# token[92] = 。, PUNCT, punct, 90
# token[93] = 「, PUNCT, punct, 96
# token[94] = クリエイティブ, ADJ, compound, 96
# token[95] = 」, PUNCT, punct, 96
# token[96] = モード, NOUN, obl, 106
# token[97] = で, ADP, case, 96
# token[98] = は, ADP, case, 96
# token[99] = 、, PUNCT, punct, 96
# token[100] = プレイヤー, NOUN, nsubj, 106
# token[101] = が, ADP, case, 100
# token[102] = 独自, ADJ, nmod, 104
# token[103] = の, ADP, case, 102
# token[104] = 世界, NOUN, obj, 106
# token[105] = を, ADP, case, 104
# token[106] = 作成, VERB, ROOT, 106
# token[107] = する, AUX, advcl, 106
# token[108] = こと, NOUN, compound, 106
# token[109] = が, ADP, case, 106
# token[110] = できる, VERB, aux, 106
# token[111] = 。, PUNCT, punct, 106

# %%
from spacy import displacy
displacy.render(doc, style='dep')
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="ja" id="fb305c333fd24f53806114a35808468e-0" class="displacy" width="16675" height="1187.0" direction="ltr" style="max-width: none; height: 1187.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">本作</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">は</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">同じ</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">ゲーム</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">エンジン</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">を</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">使用</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">し</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">て、</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">3</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">つ</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">の</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">異なる</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="2325">ゲーム</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="2500">モード</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="2675">と</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">し</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="3025">て</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">提供</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="3375">し</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="3550">て</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="3725">いる。「</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="3900">世界</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="4075">を</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="4250">救え」</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="4425">モード</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="4600">は、</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="4775">最大</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="4950">4</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="5125">人</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5125">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="5300">の</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5300">ADP</tspan>
# </text>
#
# <text class="displacy-token

# %%
for ent in doc.ents:
    print(ent.text, ent.start_char, ent.end_char, ent.label_)
# Out:
# 3つ 18 20 Countx_Other
# 最大4人 52 56 N_Person
# モンスター 70 75 Product_Other
# 協力型CO-OPモード 91 102 Doctrine_Method_Other
# バトルロイヤル 110 117 Product_Other
# 無料 127 129 Money
# 最大100人 150 156 N_Person

# %%
displacy.render(doc, style="ent")
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">本作は同じゲームエンジンを使用して、
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     3つ
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">Countx_Other</span>
# </mark>
# の異なるゲームモードとして提供している。「世界を救え」モードは、
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     最大4人
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">N_Person</span>
# </mark>
# のプレイヤーがゾンビのような
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     モンスター
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">Product_Other</span>
# </mark>
# を撃退し、オブジェクトを防御する
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     協力型CO-OPモード
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">Doctrine_Method_Other</span>
# </mark>
#  (PvE)。「
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     バトルロイヤル
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">Product_Other</span>
# </mark>
# 」モードは基本プレイ
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     無料
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">Money</span>
# </mark>
# でプレイできるバトルロイヤルゲームであり、
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     最大100人
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">N_Person</span>
# </mark>
# のプレイヤーが最後まで生き残るために他のプレイヤーと対戦する。「クリエイティブ」モードでは、プレイヤーが独自の世界を作成することができる。</div></span>

# %%
print(doc[0])
doc[0].vector
# Out:
# 本作
# array([ 0.0971664 , -0.032615  ,  0.2402084 , -0.3183388 , -0.08689716,
#         0.19915518, -0.13781515, -0.25691   ,  0.16368803, -0.16386464,
#         0.05927096,  0.13798755, -0.04528194,  0.02440662, -0.1306719 ,
#        -0.40215847, -0.19230478, -0.13009363, -0.28546476, -0.03239199,
#        -0.17497468,  0.04573978, -0.21945457,  0.0827079 , -0.00068177,
#        -0.06882177, -0.16827185,  0.16076122, -0.34113473,  0.14471994,
#        -0.03227262, -0.22802962, -0.06697726,  0.09854092,  0.08492182,
#         0.00550112,  0.0059951 , -0.23003256,  0.3004885 ,  0.05021463,
#         0.00607941, -0.02604563,  0.2653899 , -0.33912864, -0.30974334,
#        -0.2733824 ,  0.20381509,  0.06692166, -0.0221924 ,  0.00694705,
#         0.17484757,  0.19581905,  0.09187986,  0.11706802, -0.1478849 ,
#        -0.10196351, -0.12477625,  0.2654031 ,  0.16041273, -0.18606496,
#         0.03208999, -0.00821932,  0.02558343,  0.14908712, -0.19747357,
#        -0.22456339,  0.12731884,  0.2149983 , -0.23112597,  0.1613722 ,
#        -0.44382113, -0.3650146 ,  0.32848918, -0.13055731,  0.0449335 ,
#        -0.23924185,  0.0884788 , -0.12183939,  0.14670756,  0.13368645,
#        -0.17087269, -0.02013835,  0.21834603, -0.0280282 ,  0.3318566 ,
#        -0.14310299, -0.28580162,  0.12704714, -0.02654285,  0.05012591,
#        -0.29579434,  0.28275475, -0.16058786, -0.23553613,  0.08739088,
#        -0.18916166,  0.23419878, -0.06850348,  0.30188882, -0.02793378,
#         0.05069711, -0.17580268, -0.05408135,  0.1741952 , -0.21847898,
#         0.00517807,  0.14956924, -0.2564131 , -0.39685228,  0.19115527,
#        -0.03388173,  0.15889369,  0.06657645, -0.04438782,  0.070448  ,
#         0.08540557,  0.01535249,  0.06531942,  0.2466503 , -0.01929462,
#        -0.4234771 , -0.1720274 ,  0.09220537,  0.07455613,  0.02433932,
#         0.127651  ,  0.05435141,  0.07373303,  0.06166104,  0.12699279,
#        -0.00404604, -0.09825653, -0.14167085,  0.07352129, -0.3032796 ,
#         0.06262401, -0.02417169,  0.04439383,  0.18156812,  0.01454365,
#        -0.08354109,  0.24026597,  0.01774795,  0.20740722,  0.40546098,
#        -0.18206233, -0.21190807,  0.13627899,  0.11411551, -0.00894283,
#        -0.06671328,  0.17073296,  0.11752744,  0.14763866, -0.05133784,
#        -0.15018055, -0.0692322 ,  0.02147102, -0.15022881, -0.19786803,
#         0.106551  ,  0.06697677, -0.16865058, -0.06848992, -0.49331254,
#        -0.11826176,  0.00306542,  0.48500237, -0.1332495 ,  0.09056363,
#        -0.02238099,  0.34657934, -0.03243663, -0.28673998, -0.207273  ,
#         0.07783636, -0.03122923,  0.24124458, -0.06259979, -0.10096253,
#        -0.12100971, -0.09446749, -0.2602977 ,  0.08397682, -0.01740786,
#         0.01214026,  0.02668631, -0.06010627,  0.29229155,  0.02474646,
#         0.07863961,  0.01201949, -0.22695458, -0.07979334, -0.22430728,
#        -0.1289805 ,  0.24205108, -0.10339832, -0.13576955, -0.10916743,
#         0.03017494,  0.0370931 , -0.2975056 ,  0.16774264, -0.22743629,
#        -0.10332435, -0.28930062, -0.11647718,  0.30521524, -0.11423835,
#        -0.08140154, -0.00668973,  0.27924585,  0.04794643,  0.00831039,
#         0.2000015 ,  0.13265999, -0.17778362, -0.07183687,  0.05569762,
#        -0.21333097,  0.11609011,  0.2940933 ,  0.05243359,  0.00294168,
#        -0.1626412 , -0.05891721,  0.02428844,  0.108394  ,  0.03836209,
#         0.21069005,  0.14809503,  0.00539968, -0.07781869,  0.01461058,
#         0.27905166, -0.291174  , -0.02198969,  0.11745662, -0.21613377,
#         0.18796179,  0.08577172, -0.24603136, -0.08053096, -0.04029646,
#        -0.2260117 , -0.21415985, -0.42416415,  0.08215857, -0.12249359,
#        -0.21001028,  0.12063365,  0.38394648,  0.1453555 ,  0.07181008,
#        -0.10583648,  0.19389738,  0.1701123 , -0.05861935, -0.12666735,
#         0.24238695,  0.01704442,  0.3833558 ,  0.42397824, -0.22000276,
#        -0.10615709,  0.02495422,  0.00417814,  0.31174335, -0.24096453,
#         0.1398203 ,  0.40618137, -0.16094989,  0.04555533,  0.01011683,
#         0.2616067 ,  0.0478437 ,  0.00344401,  0.00318363,  0.0910169 ,
#         0.02338576, -0.14391322,  0.10411389, -0.09711834, -0.10211293,
#        -0.3122639 , -0.10551258,  0.07194448, -0.5081558 ,  0.24999578,
#         0.03145309,  0.03778582,  0.5260692 , -0.20024058,  0.15918215,
#        -0.06517328, -0.19113168,  0.4102503 ,  0.05666809,  0.13089396],
#       dtype=float32)
